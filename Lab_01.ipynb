# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdul-Mateen31/Lab01_33914/blob/main/Lab_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task:01** Basic usage of the print() function

# %%
print("Hello World!")
print("Hello Toba Tek Sing")
print("My name is Abdul-Mateen")
# Out:
# Hello World!
# Hello Toba Tek Sing
# My name is Abdul-Mateen

# %% [markdown]
# **Task:02** Declare variables, assign values of different data types, and display them using the print() function.

# %%
name="Mateen"
age=21
degree="CS"
CGPA=3.87
print("Name:",name)
print("Age:",age)
print("Degree:",degree)
print("CGPA:",CGPA)
# Out:
# Name: Mateen
# Age: 21
# Degree: CS
# CGPA: 3.87

# %% [markdown]
# **Task:03** How to take user input using the input() function

# %%
name=input("Enter Your name:")
age=int(input("Enter your age:"))
print("Welcome Mr.",name,"You are",age,"years old")
# Out:
# Enter Your name:Mateen
# Enter your age:20
# Welcome Mr. Mateen You are 20 years old

# %% [markdown]
# **Task:04** The implementation of conditional statements (if, elif, else) to make decisions based on specified conditions

# %%
marks=int(input("Enter your marks:"))
if marks>=90:
    print("Grade A")
elif marks>=80:
    print("Grade B")
elif marks>=70:
    print("Grade C")
elif marks>=60:
    print("Grade D")
else:
  print("Fail")


age=int(input("Enter your age:"))
if age>=18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")


signal_color=input("Enter the signal color:")
if signal_color=="red":
    print("Stop")
elif signal_color=="yellow":
    print("Get ready")
elif signal_color=="green":
    print("Go")
else:
    print("Invalid color")
# Out:
# Enter your marks:55
# Fail
# Enter your age:17
# You are not eligible to vote
# Enter the signal color:green
# Go

# %% [markdown]
# **Task:05** Define and call user-defined functions using the def keyword, including passing parameters and returning values.

# %%
#fucntion 01
def intro():
  print("Hi! I am GPT-6-Astra. How I can help you")
intro()

#function 02
def multipayer(a,b):
  return a*b
print(multipayer(5,6))

#function 03
def grade(a):
  if marks>=90:
    print("Grade A")
  elif marks>=80:
    print("Grade B")
  elif marks>=70:
    print("Grade C")
  elif marks>=60:
    print("Grade D")
  else:
    print("Fail")
Marks=int(input("Enter your marks:"))
print(grade(Marks))

#function 04
def adder(a,b):
  result=a+b
  return result
print(adder(3,7))

#function 05
def greet():
  print("Hi whats going on")
greet()
# Out:
# Hi! I am GPT-6-Astra. How I can help you
# 30
# Enter your marks:45
# Fail
# None
# 10
# Hi whats going on

# %% [markdown]
# **Task:06** Implementation of multithreading using the threading module to execute multiple threads concurrently and perform parallel operations.

# %%
import threading
#fucntion 01
def intro():
  print("Hi! I am GPT-6-Astra. How I can help you")

#function 02
def add(a,b):
  print(a+b)


#function 03
def info():
  print("My name is Abdul-Mateen\nI am 20 years old\nCurrently I am studying in BSCS")

t1=threading.Thread(target=intro)
t2=threading.Thread(target=add, args=(3, 10))
t3=threading.Thread(target=info)
t1.start()
t2.start()
t3.start()
# Out:
# Hi! I am GPT-6-Astra. How I can help you
# 13
# My name is Abdul-Mateen
# I am 20 years old
# Currently I am studying in BSCS

# %% [markdown]
# **Task:07** Implementation of multiprocessing using the multiprocessing module to execute tasks

# %%
import multiprocessing
#fucntion 01
def intro():
  print("Hi! I am GPT-6-Astra. How I can help you")

#function 02
def add(a,b):
  print(a+b)

#function 03
def info():
  print("My name is Abdul-Mateen\nI am 20 years old\nCurrently I am studying in BSCS")

p1=multiprocessing.Process(target=intro)
p2=multiprocessing.Process(target=add, args=(11,12))
p3=multiprocessing.Process(target=info)

p1.start()
p2.start()
p3.start()
# Out:
# Hi! I am GPT-6-Astra. How I can help you
# 23
# My name is Abdul-Mateen
# I am 20 years old
# Currently I am studying in BSCS
